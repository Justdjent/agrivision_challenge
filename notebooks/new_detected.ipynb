# %%
import geopandas as gpd

# %%
path = "/mnt/storage_4tb/ymi/geo_data/angle_net_data/row_data/58801/metric_heuristic_row_data.geojson"

# %%
df = gpd.read_file(path)

# %%
df.loc[df['coverage'] <= 0.85, 'detected'] = 0

# %%
df['detected'].sum() / len(df)
# Out:
# 0.2391304347826087

# %%
df['detected'].sum()
# Out:
# 33.0

# %%
df[['detected', 'coverage']]
# Out:
#     detected  coverage
# 0        0.0  0.000000
# 1        0.0  0.360825
# 2        0.0  0.294964
# 3        0.0  0.480226
# 4        0.0  0.021622
# 5        0.0  0.774359
# 6        0.0  0.306604
# 7        0.0  0.458716
# 8        0.0  0.418103
# 9        0.0  0.436214
# 10       0.0  0.126984
# 11       0.0  0.721190
# 12       0.0  0.485714
# 13       0.0  0.221843
# 14       0.0  0.402597
# 15       0.0  0.315113
# 16       0.0  0.462963
# 17       0.0  0.425150
# 18       0.0  0.252874
# 19       0.0  0.252078
# 20       0.0  0.195122
# 21       0.0  0.283465
# 22       0.0  0.546154
# 23       0.0  0.365915
# 24       0.0  0.334140
# 25       0.0  0.267773
# 26       0.0  0.352273
# 27       0.0  0.290466
# 28       0.0  0.247265
# 29       0.0  0.432836
# 30       0.0  0.298539
# 31       0.0  0.404908
# 32       0.0  0.287169
# 33       0.0  0.362550
# 34       0.0  0.176056
# 35       0.0  0.300000
# 36       0.0  0.458333
# 37       0.0  0.424528
# 38       0.0  0.191176
# ...
