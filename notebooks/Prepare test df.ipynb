# %%
import pandas as pd
import os

# %%
trainval_df = ""

# %%
test_dir = "/mnt/d/work/data/agrivision/test"

# %%
images_dir = os.path.join(test_dir, "images", "rgb")

# %%
image_list = os.listdir(images_dir)

# %%
image_list
# Out:
# ['1FPBNGD9F_1105-7380-1617-7892.jpg',
#  '1FPBNGD9F_1105-7892-1617-8404.jpg',
#  '1FPBNGD9F_1196-3937-1708-4449.jpg',
#  '1FPBNGD9F_1272-6823-1784-7335.jpg',
#  '1FPBNGD9F_1617-6868-2129-7380.jpg',
#  '1FPBNGD9F_1617-7380-2129-7892.jpg',
#  '1FPBNGD9F_1617-7892-2129-8404.jpg',
#  '1FPBNGD9F_1708-3937-2220-4449.jpg',
#  '1FPBNGD9F_2129-6868-2641-7380.jpg',
#  '1FPBNGD9F_2129-7380-2641-7892.jpg',
#  '1FPBNGD9F_2129-7892-2641-8404.jpg',
#  '1FPBNGD9F_3110-4667-3622-5179.jpg',
#  '1FPBNGD9F_3480-5116-3992-5628.jpg',
#  '1FPBNGD9F_3491-5431-4003-5943.jpg',
#  '1FPBNGD9F_3622-4667-4134-5179.jpg',
#  '1FPBNGD9F_3740-4234-4252-4746.jpg',
#  '1FPBNGD9F_3917-3817-4429-4329.jpg',
#  '1FPBNGD9F_3956-4952-4468-5464.jpg',
#  '1FPBNGD9F_3956-5976-4468-6488.jpg',
#  '1FPBNGD9F_3989-4490-4501-5002.jpg',
#  '1FPBNGD9F_4003-5431-4515-5943.jpg',
#  '1FPBNGD9F_4252-4234-4764-4746.jpg',
#  '1FPBNGD9F_4429-3817-4941-4329.jpg',
#  '1FPBNGD9F_4468-4952-4980-5464.jpg',
#  '1FPBNGD9F_4468-5464-4980-5976.jpg',
# ...

# %%
test_df = pd.DataFrame(image_list, columns=['name'])

# %%
test_df.to_csv('test.csv', index=False)
