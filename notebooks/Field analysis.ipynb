# %%
import os
import pandas as pd

# %%
test_images_path = "/home/user/projects/agrivision/data/Agriculture-Vision/test/images/rgb/"
train_images_path = "/home/user/projects/agrivision/data/Agriculture-Vision/train/images/rgb"
val_images_path = "/home/user/projects/agrivision/data/Agriculture-Vision/val/images/rgb"

# %%
test_img_names = os.listdir(test_images_path)
train_img_names = os.listdir(train_images_path)
val_img_names = os.listdir(val_images_path)

# %%
test_farms = [name.split("_")[0] for name in test_img_names]
train_farms = [name.split("_")[0] for name in train_img_names]
val_farms = [name.split("_")[0] for name in val_img_names]

# %%
df = pd.DataFrame()
df['farm_name'] = test_farms

# %%
df['farm_name'].value_counts()
# Out:
# TWVLWA3LV    186
# D1M7QKGIN    182
# GJQ4F4C6F    145
# GID71T4G7    141
# AA6FKGHN2    134
# KJLVREIYD    126
# 4AZJLIGYZ    116
# ND4EHNNG3    115
# HLMFICZ9F    105
# CRD6WRWZ7    102
# 1FPBNGD9F     98
# HXAKBCBWD     96
# CZ91HDRM3     88
# 8ZJP16LPU     84
# WF16D3L3I     77
# BAB2VIYP2     71
# 2F1UWUYLH     69
# BATYKFY7V     67
# 2K21T1ZGV     57
# Y6UDNUNDT     56
# I9749FXZX     53
# LL34JUATL     51
# BWLVYMYWL     51
# CEXNWCRQW     49
# I8GHZKUWN     49
# M8PJ2RQGG     43
# VLH93CKH3     43
# AEV8IREHQ     39
# 8C2EDD984     39
# G9B6JET91     37
#             ...
# ULUHW4VXG      5
# NTYNIQJ9Y      4
# NDEWR66NP      4
# 1FYR4LX8Y      4
# CNAW17IHZ      3
# UTVYEPQN1      3
# LW3UKG9RR      3
# FDZTG9NU6      3
# LY2836DLI      3
# 2DKYNFE7F      3
# AC3DC66N9      3
# 1IKD27T9J      2
# ZVHNI4UFQ      2
# 3NBHVX97R      2
# W4FNWP2RD      2
# Q799QLAFK      2
# W74DNCGB8      2
# 2AX4CD6GI      2
# AHPWNC774      2
# HHEWRH664      2
# ZP4Q9JNPE      2
# ...

# %%
set(val_farms).intersection(set(test_farms))
# Out:
# set()

# %%
# Out:
# {'11T3V93AF',
#  '11UBQLX1B',
#  '12GWAPNV1',
#  '13MQGW9CZ',
#  '17FCUVCMI',
#  '17XVPGGZ1',
#  '18X67NLZ2',
#  '1C11HIBEV',
#  '1DJX4RH9N',
#  '1J7JL2PDK',
#  '1L7F6F74T',
#  '1LNFVP1VD',
#  '1W6YEHJJU',
#  '24M49T6CC',
#  '26AB3WKTK',
#  '26DRBUF64',
#  '26G8P9NJF',
#  '29PWCB1DI',
#  '2C7M9ACWY',
#  '2CTF1YW2N',
#  '2CVV62WDV',
#  '2FPNYIQY1',
#  '2HFHD3N34',
#  '2J7111V4A',
#  '2KIH2Y23Z',
#  '2P1L94AKV',
#  '2PJHLLWTV',
#  '2QCKUWN6F',
#  '2U827769J',
#  '2WXFGL2AU',
#  '2XIW7GVPV',
#  '2Z3HK7FB7',
#  '2Z6V32VW4',
#  '2Z9UV9DHA',
#  '2Z9YGCA94',
#  '336WPRP8X',
#  '386BB49EA',
#  '38ZTBVF2D',
#  '393VYUQ83',
#  '3A8MTTLYD',
#  '3D7CVWEG3',
#  '3EW7ZI4I6',
#  '3FJMLWRT2',
#  '3KYIGUGBQ',
#  '3L2JTWHVX',
#  '3N84YAMUW',
#  '3N9X643LR',
#  '3R89W78EX',
#  '3RMCTCKVD',
#  '3WR4DRMU8',
#  '3Z98FNHVW',
#  '42DT9R2QN',
#  '489IEPCE6',
#  '49KQ94HCB',
#  '4AFCPFI7E',
#  '4AI2XJDRL',
#  '4AXQ9D29C',
#  '4DAFLP3Y8',
#  '4EKYNMJ6H',
#  '4EMV17YYF',
#  '4HMV8PEAM',
#  '4K98Q2K8F',
# ...
